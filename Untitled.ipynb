# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
df =pd.read_csv("https://www.football-data.co.uk/new/BRA.csv")

# %%
df.head()
# Out:
#   Country   League  Season        Date   Time          Home         Away   HG  \
# 0  Brazil  Serie A    2012  19/05/2012  22:30     Palmeiras   Portuguesa  1.0
# 1  Brazil  Serie A    2012  19/05/2012  22:30  Sport Recife  Flamengo RJ  1.0
# 2  Brazil  Serie A    2012  20/05/2012  01:00   Figueirense      Nautico  2.0
# 3  Brazil  Serie A    2012  20/05/2012  20:00   Botafogo RJ    Sao Paulo  4.0
# 4  Brazil  Serie A    2012  20/05/2012  20:00   Corinthians   Fluminense  0.0
#
#     AG Res  ...  MaxCA  AvgCH  AvgCD  AvgCA  BFECH  BFECD  BFECA  B365CH  \
# 0  1.0   D  ...   5.31   1.69   3.50   4.90    NaN    NaN    NaN     NaN
# 1  1.0   D  ...   2.70   2.59   3.23   2.58    NaN    NaN    NaN     NaN
# 2  1.0   H  ...   7.22   1.59   3.67   5.64    NaN    NaN    NaN     NaN
# 3  2.0   H  ...   3.15   2.35   3.26   2.84    NaN    NaN    NaN     NaN
# 4  1.0   A  ...   4.41   1.89   3.33   3.89    NaN    NaN    NaN     NaN
#
#    B365CD  B365CA
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Country', 'League', 'Season', 'Date', 'Time', 'Home', 'Away', 'HG',
#        'AG', 'Res', 'PSCH', 'PSCD', 'PSCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH',
#        'AvgCD', 'AvgCA', 'BFECH', 'BFECD', 'BFECA', 'B365CH', 'B365CD',
#        'B365CA'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5519 entries, 0 to 5518
# Data columns (total 25 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  5519 non-null   str
#  1   League   5519 non-null   str
#  2   Season   5519 non-null   int64
#  3   Date     5519 non-null   str
#  4   Time     5519 non-null   str
#  5   Home     5519 non-null   str
#  6   Away     5519 non-null   str
#  7   HG       5518 non-null   float64
#  8   AG       5518 non-null   float64
#  9   Res      5518 non-null   str
#  10  PSCH     5275 non-null   float64
#  11  PSCD     5275 non-null   float64
#  12  PSCA     5275 non-null   float64
#  13  MaxCH    5519 non-null   float64
#  14  MaxCD    5519 non-null   float64
#  15  MaxCA    5519 non-null   float64
#  16  AvgCH    5519 non-null   float64
#  17  AvgCD    5519 non-null   float64
#  18  AvgCA    5519 non-null   float64
#  19  BFECH    784 non-null    float64
#  20  BFECD    784 non-null    float64
#  21  BFECA    784 non-null    float64
#  22  B365CH   401 non-null    float64
#  23  B365CD   401 non-null    float64
#  24  B365CA   401 non-null    float64
# dtypes: float64(17), int64(1), str(7)
# memory usage: 1.1 MB

# %%
df.isna().sum()
# Out:
# Country       0
# League        0
# Season        0
# Date          0
# Time          0
# Home          0
# Away          0
# HG            1
# AG            1
# Res           1
# PSCH        244
# PSCD        244
# PSCA        244
# MaxCH         0
# MaxCD         0
# MaxCA         0
# AvgCH         0
# AvgCD         0
# AvgCA         0
# BFECH      4735
# BFECD      4735
# BFECA      4735
# B365CH     5118
# B365CD     5118
# B365CA     5118
# dtype: int64

# %%
df.shape
# Out:
# (5519, 25)

# %%
df = df.loc[:, ['Date','Season','Home', 'Away', 'HG','AG', 'Res', 'PSCH', 'PSCD', 'PSCA']]

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Date      0
# Season    0
# Home      0
# Away      0
# HG        0
# AG        0
# Res       0
# PSCH      0
# PSCD      0
# PSCA      0
# dtype: int64

# %%
df.groupby("Home").agg(
    media_odd = ('PSCH','mean')
).reset_index()
# Out:
#               Home  media_odd
# 0       America MG   2.913263
# 1     Athletico-PR   2.210482
# 2      Atletico GO   2.916316
# 3      Atletico-MG   1.788106
# 4             Avai   3.292105
# 5            Bahia   2.355990
# 6      Botafogo RJ   2.434115
# 7       Bragantino   2.178125
# 8              CSA   4.408421
# 9            Ceara   2.508108
# 10  Chapecoense-SC   2.893788
# 11     Corinthians   2.100304
# 12        Coritiba   2.567778
# 13        Criciuma   2.747895
# 14        Cruzeiro   1.915749
# 15          Cuiaba   2.855789
# 16     Figueirense   2.765921
# 17     Flamengo RJ   1.760795
# 18      Fluminense   2.211597
# 19       Fortaleza   2.334697
# 20           Goias   3.000150
# 21          Gremio   1.919429
# 22   Internacional   1.913918
# 23       Joinville   3.168947
# 24       Juventude   3.367297
# 25        Mirassol   2.372941
# 26         Nautico   2.836316
# 27       Palmeiras   1.755510
# 28          Parana   4.492632
# 29     Ponte Preta   2.419579
# 30      Portuguesa   2.575000
# 31      Santa Cruz   2.533684
# 32          Santos   2.166107
# 33       Sao Paulo   1.919659
# 34    Sport Recife   2.656071
# 35           Vasco   2.624362
# 36         Vitoria   2.534046

# %%
df_raw = df.copy()

# %% [markdown]
# ## Analise das variaveis

# %%
class_counts = df_raw['Res'].value_counts()
print('Proporção', class_counts / len(df_raw))
# Out:
# Proporção Res
# H    0.485498
# D    0.268246
# A    0.246256
# Name: count, dtype: float64

# %%
df_raw[['PSCH', 'PSCD', 'PSCA']].describe()
# Out:
#               PSCH         PSCD         PSCA
# count  5275.000000  5275.000000  5275.000000
# mean      2.309354     3.635761     4.677033
# std       0.949609     0.655082     2.467124
# min       1.080000     2.540000     1.150000
# 25%       1.700000     3.240000     2.990000
# 50%       2.080000     3.440000     4.030000
# 75%       2.620000     3.830000     5.700000
# max      17.680000    12.250000    29.580000

# %% [markdown]
# # Engenharia de features

# %%
df_raw['Date_parsed'] =pd.to_datetime(df_raw['Date'], format= '%d/%m/%Y')
df_raw = df_raw.sort_values('Date_parsed').reset_index(drop=True)

# %%
# covenverter odds em Probabilidade 
df_raw['p_home'] = 1/df_raw['PSCH']
df_raw['p_draw'] = 1/df_raw['PSCD']
df_raw['p_away'] = 1/df_raw['PSCA']

# %%
# remover o juice da casa de aposta
total = ( 
    df_raw['p_home'] +
    df_raw['p_draw'] +
    df_raw['p_away']
)

# %%
df_raw["p_home"] /= total
df_raw["p_away"] /= total
df_raw["p_draw"] /= total

# %%
# diferença porbabilidade casa e fora 
df_raw['dif_prob'] = df_raw['p_home'] - df_raw['p_away']

# %%
df_raw['goal_diff'] = df_raw['HG'] - df_raw['AG']

# %%
df_raw['goal_total'] = df_raw['HG'] + df_raw['AG']

# %% [markdown]
# # Categorizar as probabilidades do times

# %%
labels = [
    "Grande Zebra",
    "Zebra",
    "Leve Zebra",
    "Equilibrado",
    "Leve Favorito",
    "Favorito",
    "Super Favorito"
]

# %%
df_raw["bucket_favoritismo"] = pd.qcut(
    df_raw["dif_prob"],
    q=7,
    labels=labels,
    duplicates="drop"
)

# %%
df_raw.tail()
# Out:
#             Date  Season         Home       Away   HG   AG Res  PSCH  PSCD  \
# 5270  07/12/2025    2025        Ceara  Palmeiras  1.0  3.0   A  1.99  3.31
# 5271  07/12/2025    2025  Botafogo RJ  Fortaleza  4.0  2.0   H  1.70  4.00
# 5272  07/12/2025    2025  Atletico-MG      Vasco  5.0  0.0   H  1.51  4.11
# 5273  07/12/2025    2025  Corinthians  Juventude  1.0  1.0   D  1.76  3.39
# 5274  07/12/2025    2025      Vitoria  Sao Paulo  1.0  0.0   H  2.47  3.08
#
#       PSCA Date_parsed    p_home    p_draw    p_away  dif_prob  goal_diff  \
# 5270  3.98  2025-12-07  0.475917  0.286125  0.237958  0.237958       -2.0
# 5271  4.58  2025-12-07  0.556737  0.236613  0.206649  0.350088        2.0
# 5272  6.65  2025-12-07  0.627170  0.230420  0.142410  0.484760        5.0
# 5273  5.12  2025-12-07  0.536791  0.278688  0.184522  0.352269        0.0
# 5274  3.10  2025-12-07  0.384804  0.308593  0.306602  0.078202        1.0
#
#       goal_total bucket_favoritismo
# 5270         4.0        Equilibrado
# 5271         6.0      Leve Favorito
# 5272         5.0     Super Favorito
# 5273         2.0      Leve Favorito
# 5274         1.0         Leve Zebra

# %% [markdown]
# # Média de gols dos ultimos 5 jogos

# %%
# média de gols nos ultimos 5 jogos 

df_raw['home_last5_goals'] =(
    df_raw.groupby('Home')['HG']
    .transform(lambda s: s.shift().rolling(window=5, min_periods=1).mean())
    
)

df_raw['away_last5_goals'] =(
    df_raw.groupby('Away')['AG']
    .transform(lambda s: s.shift().rolling(window=5, min_periods=1).mean())
)

# %%
# força da defesa 
df_raw['home_last5_concede'] = df_raw.groupby('Home')['AG'].transform(
    lambda s: s.shift().rolling(5, min_periods=1).mean()
)

df_raw['away_last5_concede'] = df_raw.groupby('Away')['HG'].transform(
    lambda s: s.shift().rolling(5, min_periods=1).mean()
)

# %% [markdown]
# # Média exponencial do gols EWMA

# %%
df_raw['home_ewma_5_goals'] = (
    df_raw.groupby('Home')['HG']
    .transform(lambda s : s.shift().ewm(span = 5, adjust = False).mean())
)

df_raw['away_ewma_5_goals'] = (
    df_raw.groupby('Away')['AG']
    .transform(lambda s : s.shift().ewm(span = 5, adjust = False).mean())
)

# %% [markdown]
# # Winrate dos ultimos 5 jogos

# %%
res_map ={ 'H' :2, 'D': 1, 'A' : 0}
df_raw['Res_num'] = df_raw['Res'].map(res_map)

# %%
df_raw['home_last5_winrate'] =(
    df_raw.groupby('Home')['Res_num']
    .transform(lambda s: s.shift().rolling(5, min_periods= 1).apply(lambda x : (x==2).mean()))
)

df_raw['away_last5_winrate'] =(
    df_raw.groupby('Away')['Res_num']
    .transform(lambda s: s.shift().rolling(5, min_periods= 1).apply(lambda x : (x==0).mean()))
)

# %%
df_raw["home_points"] = np.select(
    [
        df_raw["Res_num"] == 2,
        df_raw["Res_num"] == 1,
        df_raw["Res_num"] == 0
    ],
    [
        3,
        1,
        0
    ]
)

df_raw["away_points"] = np.select(
    [
        df_raw["Res_num"] == 0,
        df_raw["Res_num"] == 1,
        df_raw["Res_num"] == 2
    ],
    [
        3,
        1,
        0
    ]
)

# %% [markdown]
# # PONTOS NAS ULTIMAS 5 PARTIDAS PPG

# %%
df_raw["home_last5_ppg"] = (
    df_raw
    .groupby("Home")["away_points"]
    .transform(
        lambda s: s.shift().rolling(5, min_periods=1).mean()
    )
)


df_raw["away_last5_ppg"] = (
    df_raw
    .groupby("Away")["away_points"]
    .transform(
        lambda s: s.shift().rolling(5, min_periods=1).mean()
    )
)

# %% [markdown]
# # CALCULANDO O CAOS "ENTROPIA"

# %%
H_MAX = np.log2(3)

def calc_entropy(row, normalize=True):

    p = np.array([
        row["p_home"],
        row["p_draw"],
        row["p_away"]
    ])

    p = p[p > 0]

    h = -(p * np.log2(p)).sum()

    if normalize:
        h /= H_MAX

    return h

df_raw["entropy"] = df_raw.apply(calc_entropy, axis=1)

# %% [markdown]
# | Entropia | Interpretação                   |
# | -------: | ------------------------------- |
# |     0.00 | Resultado praticamente definido |
# |     0.20 | Super favorito                  |
# |     0.40 | Favorito                        |
# |     0.60 | Leve favorito                   |
# |     0.80 | Jogo equilibrado                |
# |     1.00 | Máxima incerteza                |

# %%
# SELECIONAR UMA AMOSTRA ALEATÓRIA
df_raw.sample(10)
# Out:
#             Date  Season          Home          Away   HG   AG Res  PSCH  \
# 617   29/09/2013    2013   Flamengo RJ      Criciuma  4.0  1.0   H  1.50
# 1762  15/09/2016    2016     Palmeiras   Flamengo RJ  1.0  1.0   D  1.97
# 1011  04/10/2014    2014      Coritiba  Athletico-PR  1.0  0.0   H  1.90
# 4769  17/08/2024    2024        Gremio         Bahia  0.0  2.0   A  2.80
# 1028  09/10/2014    2014        Gremio  Sport Recife  2.0  0.0   H  1.50
# 773   27/04/2014    2014   Figueirense         Bahia  0.0  2.0   A  3.24
# 4111  16/10/2022    2022          Avai    Fluminense  0.0  3.0   A  4.45
# 831   28/05/2014    2014  Sport Recife        Gremio  0.0  0.0   D  3.86
# 4091  05/10/2022    2022         Ceara         Goias  1.0  1.0   D  1.69
# 1847  29/10/2016    2016   Figueirense        Gremio  0.0  0.0   D  2.50
#
#       PSCD  PSCA  ... home_ewma_5_goals  away_ewma_5_goals  Res_num  \
# 617   4.43  7.71  ...          1.599348           1.376873        2
# 1762  3.61  4.16  ...          1.844925           1.642580        1
# 1011  3.47  4.75  ...          1.635834           0.277518        2
# 4769  3.28  2.70  ...          1.122848           0.928137        0
# 1028  4.28  7.97  ...          0.598554           0.178195        2
# 773   3.38  2.38  ...          1.272205           1.078608        0
# 4111  3.40  1.96  ...          0.957547           1.202275        0
# 831   3.47  2.09  ...          1.480229           0.539891        1
# 4091  3.72  5.83  ...          0.795506           1.169295        1
# 1847  3.18  3.21  ...          1.174582           0.687425        1
#
#       home_last5_winrate  away_last5_winrate  home_points  away_points  \
# 617                  0.4                 0.4            3            0
# 1762                 0.4                 0.6            1            1
# 1011                 0.6                 0.0            3            0
# 4769                 0.6                 0.2            0            3
# 1028                 0.6                 0.0            3            0
# 773                  0.2                 0.4            0            3
# 4111                 0.2                 0.2            0            3
# 831                  0.4                 0.2            1            1
# 4091                 0.2                 0.4            1            1
# 1847                 0.4                 0.2            1            1
#
#      home_last5_ppg  away_last5_ppg   entropy
# 617             1.4             1.4  0.795760
# 1762            1.0             2.0  0.948211
# 1011            0.8             0.0  0.932178
# 4769            0.8             0.8  0.996872
# 1028            0.8             0.0  0.795579
# 773             1.6             1.4  0.988216
# 4111            2.0             0.6  0.944891
# 2933                 0.8                 0.0            3            0
# 2968                 0.6                 0.0            3            0
# 3011                 0.8                 0.4            3            0
# 3023                 0.8                 0.0            3            0
# 3058                 0.4                 0.2            1            1
# 3356                 0.6                 0.2            3            0
# 3523                 0.6                 0.0            3            0
# 3637                 0.6                 0.0            3            0
# 3795                 1.0                 0.0            3            0
# 3860                 0.4                 0.2            3            0
# 3870                 0.6                 0.0            3            0
# 4057                 0.6                 0.0            3            0
# 4121                 0.6                 0.0            3            0
# 4136                 0.2                 0.0            3            0
# 4169                 0.6                 0.0            0            3
# 4535                 0.8                 0.0            3            0
# 4543                 0.4                 0.6            3            0
# 4879                 0.6                 0.0            1            1
# 4975                 0.4                 0.4            3            0
# 5137                 1.0                 0.0            3            0
# 5256                 1.0                 0.0            3            0
#
#      home_last5_ppg  away_last5_ppg   entropy
# 691             0.2             0.8  0.590968
# 739             0.0             0.6  0.586835
# 745             0.8             0.0  0.543036
# 752             1.0             0.6  0.576889
# 870             0.2             1.4  0.585008
# 1130            0.2             0.2  0.587427
# 1229            1.4             0.0  0.578225
# 1370            1.2             0.2  0.595623
# 1892            0.8             0.2  0.590180
# 1893            0.2             0.0  0.554838
# 1985            0.2             0.8  0.598581
# 2014            0.6             0.6  0.546481
# 2625            2.2             1.8  0.539995
# 2653            0.0             1.0  0.576121
# 2705            0.6             0.5  0.585676
# 2860            0.4             1.0  0.551834
# 2868            1.0             1.0  0.570150
# 2917            0.2             0.4  0.509480
# 2933            0.2             0.2  0.378048
# 2968            0.8             0.0  0.497953
# 3011            0.2             1.6  0.598838
# 3023            0.2             0.2  0.429599
# 3058            1.4             0.8  0.549226
# 3356            0.8             0.6  0.577740
# 3523            1.2             0.6  0.559050
# 3637            1.2             0.0  0.584660
# 3795            0.0             0.2  0.556503
# 3860            1.4             0.8  0.528323
# 3870            0.8             0.2  0.582922
# 4057            0.8             0.2  0.525074
# 4121            0.4             0.4  0.495776
# 4136            1.6             0.0  0.546179
# 4169            0.8             0.2  0.528460
# 4535            0.6             0.4  0.547963
# 4543            1.4             1.8  0.560979
# 4879            0.4             0.4  0.599148
# 4975            0.6             1.4  0.578519
# 5137            0.0             0.6  0.560107
# 5256            0.0             0.2  0.575532
#
# [39 rows x 32 columns]

# %%
df_raw.columns
# Out:
# Index(['Date', 'Season', 'Home', 'Away', 'HG', 'AG', 'Res', 'PSCH', 'PSCD',
#        'PSCA', 'Date_parsed', 'p_home', 'p_draw', 'p_away', 'dif_prob',
#        'goal_diff', 'goal_total', 'bucket_favoritismo', 'home_last5_goals',
#        'away_last5_goals', 'home_last5_concede', 'away_last5_concede',
#        'home_ewma_5_goals', 'away_ewma_5_goals', 'Res_num',
#        'home_last5_winrate', 'away_last5_winrate', 'home_points',
#        'away_points', 'home_last5_ppg', 'away_last5_ppg', 'entropy'],
#       dtype='str')

# %% [markdown]
# # lucratividade por time

# %%
df_raw['ret_home'] = np.where(df_raw['Res'] =='H', df_raw['PSCH'] -1, -1)
df_raw['ret_draw'] = np.where(df_raw['Res'] =='D', df_raw['PSCD'] -1, -1)
df_raw['ret_away'] = np.where(df_raw['Res'] =='A', df_raw['PSCA'] -1, -1)

# %%
df_raw.to_csv("dados_processados.csv", index=False)
